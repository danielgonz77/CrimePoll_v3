# %%
import pandas as pd
import numpy as np
import seaborn as sns
from tqdm import tqdm, trange

# %%
o3_2016 = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\2016O3.csv")
o3_2017 = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\2017O3.csv")
o3_2018 = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\2018O3.csv")
o3_2019 = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\2019O3.csv")
o3_2020 = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\2020O3.csv")

# %%
df_o3_2016 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Valor'])
df_o3_2017 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Valor'])
df_o3_2018 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Valor'])
df_o3_2019 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Valor'])
df_o3_2020 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Valor'])

# %%
df_o3_2016
# Out:
# Empty DataFrame
# Columns: [Dia, Mes, Anio, Hora, Lugar, Valor]
# Index: []

# %%
header_list_o3_2016 = list(o3_2016)
header_list_o3_2017 = list(o3_2017)
header_list_o3_2018 = list(o3_2018)
header_list_o3_2019 = list(o3_2019)
header_list_o3_2020 = list(o3_2020)

# %%
df_o3_2017
# Out:
# Empty DataFrame
# Columns: [Dia, Mes, Anio, Hora, Lugar, Valor]
# Index: []

# %%
cat_estacion = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\cat_estacion.csv")
cat_parametros = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\cat_parametros.csv")
cat_unidades = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\cat_unidades.csv")

# %%
for j in range(len(o3_2016)-1):
    
    for i in range(len(header_list_o3_2016)-2):
        date = pd.to_datetime(o3_2016.loc[j][0])
        toAppend = { 
        'Dia': date.day, 
        'Mes': date.month,
        'Anio': date.year,
        'Hora': o3_2016.loc[j][1], 
        'Lugar': cat_estacion.loc[cat_estacion['cve_estac'] == header_list_o3_2016[i+2]]['nom_estac'].values[0],
        'Valor': o3_2016.loc[j][i+2]}
        df2 = pd.DataFrame([toAppend])
        df_o3_2016 = pd.concat([df_o3_2016, df2], ignore_index=True, axis = 0)

# %%
df_o3_2016
# Out:
#        Dia Mes  Anio Hora                Lugar Valor
# 0        1   1  2016    1              Acolman   -99
# 1        1   1  2016    1         Ajusco Medio    38
# 2        1   1  2016    1               Ajusco    19
# 3        1   1  2016    1             Atizapan   -99
# 4        1   1  2016    1        Benito Juarez   -99
# ...     ..  ..   ...  ...                  ...   ...
# 298617  31  12  2016   23            Tultitlan     2
# 298618  31  12  2016   23       UAM Xochimilco    13
# 298619  31  12  2016   23       UAM Iztapalapa    15
# 298620  31  12  2016   23  Villa de las Flores     4
# 298621  31  12  2016   23             Xalostoc     5
#
# [298622 rows x 6 columns]

# %%
df_2017_f = o3_2017.iloc[:, :1]
df_2017_f["FECHA"]
# Out:
# 0       01/01/2017
# 1       01/01/2017
# 2       01/01/2017
# 3       01/01/2017
# 4       01/01/2017
#            ...
# 8755    31/12/2017
# 8756    31/12/2017
# 8757    31/12/2017
# 8758    31/12/2017
# 8759    31/12/2017
# Name: FECHA, Length: 8760, dtype: object

# %%
format1 ="%d/%m/%Y"

# Convert and store datetime in new format
#df_2017_f1 = pd.DataFrame()
o3_2017["FECHA"] = pd.to_datetime(o3_2017["FECHA"], format=format1)
o3_2017
# Out:
#           FECHA  HORA  ACO  AJM  AJU  ATI  BJU  CAM  CCA  CHO  ...  SAG  SFE  \
# 0    2017-01-01     1  -99   30  -99    8    2   12    8    9  ...    2   30
# 1    2017-01-01     2  -99   29  -99    5    1    7    8    4  ...    2   35
# 2    2017-01-01     3  -99   30  -99    2    2    9    2   19  ...    4   33
# 3    2017-01-01     4    4   31    6    2    2    4    1   10  ...    3   28
# 4    2017-01-01     5    5   30    5    2    2    2    1    4  ...    5   26
# ...         ...   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 8755 2017-12-31    20   11   67   39   41   48  -99  -99  -99  ...   32   31
# 8756 2017-12-31    21    6   57   23   15   38  -99  -99  -99  ...   28   23
# 8757 2017-12-31    22   11   32   22   14   22  -99  -99  -99  ...   15   21
# 8758 2017-12-31    23   13   33   22   21   24  -99  -99  -99  ...    8   12
# 8759 2017-12-31    24   10   34   19   23   17  -99  -99  -99  ...    8   19
#
#       SJA  TAH  TLA  TLI  UAX  UIZ  VIF  XAL
# ...

# %%
o3_2017.loc[0][0].day
# Out:
# 1

# %%
dia = [i.day for i in df_2017_f["FECHA"]]
mes = [i.month for i in df_2017_f["FECHA"]]
anio = [i.year for i in df_2017_f["FECHA"]]

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2016.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_o3_2016.to_csv(filepath)

# %%
for j in range(len(o3_2017)-1):
    
    for i in range(len(header_list_o3_2017)-2):
        date = o3_2017.loc[j][0]
        toAppend = { 
        'Dia': date.day, 
        'Mes': date.month,
        'Anio': date.year,
        'Hora': o3_2017.loc[j][1], 
        'Lugar': cat_estacion.loc[cat_estacion['cve_estac'] == header_list_o3_2017[i+2]]['nom_estac'].values[0],
        'Valor': o3_2017.loc[j][i+2]}
        df2 = pd.DataFrame([toAppend])
        df_o3_2017 = pd.concat([df_o3_2017, df2], ignore_index=True, axis = 0)

# %%
o3_2020["FECHA"]
# Out:
# 0         1/1/2020
# 1         1/1/2020
# 2         1/1/2020
# 3         1/1/2020
# 4         1/1/2020
#            ...
# 8779    12/31/2020
# 8780    12/31/2020
# 8781    12/31/2020
# 8782    12/31/2020
# 8783    12/31/2020
# Name: FECHA, Length: 8784, dtype: object

# %%
format1 ="%m/%d/%Y"

o3_2018["FECHA"] = pd.to_datetime(o3_2018["FECHA"], format=format1)
o3_2019["FECHA"] = pd.to_datetime(o3_2019["FECHA"], format=format1)
o3_2020["FECHA"] = pd.to_datetime(o3_2020["FECHA"], format=format1)

# %%
for j in range(len(o3_2018)-1):
    
    for i in range(len(header_list_o3_2018)-2):
        date = o3_2018.loc[j][0]
        toAppend = { 
        'Dia': date.day, 
        'Mes': date.month,
        'Anio': date.year,
        'Hora': o3_2018.loc[j][1], 
        'Lugar': cat_estacion.loc[cat_estacion['cve_estac'] == header_list_o3_2018[i+2]]['nom_estac'].values[0],
        'Valor': o3_2018.loc[j][i+2]}
        df2 = pd.DataFrame([toAppend])
        df_o3_2018 = pd.concat([df_o3_2018, df2], ignore_index=True, axis = 0)

# %%
for j in range(len(o3_2019)-1):
    
    for i in range(len(header_list_o3_2019)-2):
        date = o3_2019.loc[j][0]
        toAppend = { 
        'Dia': date.day, 
        'Mes': date.month,
        'Anio': date.year,
        'Hora': o3_2019.loc[j][1], 
        'Lugar': cat_estacion.loc[cat_estacion['cve_estac'] == header_list_o3_2019[i+2]]['nom_estac'].values[0],
        'Valor': o3_2019.loc[j][i+2]}
        df2 = pd.DataFrame([toAppend])
        df_o3_2019 = pd.concat([df_o3_2019, df2], ignore_index=True, axis = 0)

# %%
for j in range(len(o3_2020)-1):
    
    for i in range(len(header_list_o3_2020)-2):
        date = o3_2020.loc[j][0]
        toAppend = { 
        'Dia': date.day, 
        'Mes': date.month,
        'Anio': date.year,
        'Hora': o3_2020.loc[j][1], 
        'Lugar': cat_estacion.loc[cat_estacion['cve_estac'] == header_list_o3_2020[i+2]]['nom_estac'].values[0],
        'Valor': o3_2020.loc[j][i+2]}
        df2 = pd.DataFrame([toAppend])
        df_o3_2020 = pd.concat([df_o3_2020, df2], ignore_index=True, axis = 0)

# %%
df_o3_2017
# Out:
#        Dia Mes  Anio Hora                Lugar Valor
# 0        1   1  2017    1              Acolman   -99
# 1        1   1  2017    1         Ajusco Medio    30
# 2        1   1  2017    1               Ajusco   -99
# 3        1   1  2017    1             Atizapan     8
# 4        1   1  2017    1        Benito Juarez     2
# ...     ..  ..   ...  ...                  ...   ...
# 297801  31  12  2017   23            Tultitlan     2
# 297802  31  12  2017   23       UAM Xochimilco    17
# 297803  31  12  2017   23       UAM Iztapalapa    11
# 297804  31  12  2017   23  Villa de las Flores     9
# 297805  31  12  2017   23             Xalostoc     5
#
# [297806 rows x 6 columns]

# %%
df_o3_2018
# Out:
#        Dia Mes  Anio Hora                Lugar Valor
# 0        1   1  2018    1              Acolman     8
# 1        1   1  2018    1         Ajusco Medio    31
# 2        1   1  2018    1               Ajusco    17
# 3        1   1  2018    1             Atizapan    17
# 4        1   1  2018    1        Benito Juarez    22
# ...     ..  ..   ...  ...                  ...   ...
# 297801  31  12  2018   23            Tultitlan     6
# 297802  31  12  2018   23       UAM Xochimilco     7
# 297803  31  12  2018   23       UAM Iztapalapa     3
# 297804  31  12  2018   23  Villa de las Flores     2
# 297805  31  12  2018   23             Xalostoc     5
#
# [297806 rows x 6 columns]

# %%
df_o3_2019
# Out:
#        Dia Mes  Anio Hora                Lugar Valor
# 0        1   1  2019    1              Acolman   -99
# 1        1   1  2019    1         Ajusco Medio   -99
# 2        1   1  2019    1               Ajusco   -99
# 3        1   1  2019    1             Atizapan   -99
# 4        1   1  2019    1        Benito Juarez   -99
# ...     ..  ..   ...  ...                  ...   ...
# 324078  31  12  2019   23            Tultitlan     4
# 324079  31  12  2019   23       UAM Xochimilco    17
# 324080  31  12  2019   23       UAM Iztapalapa     8
# 324081  31  12  2019   23  Villa de las Flores     2
# 324082  31  12  2019   23             Xalostoc     8
#
# [324083 rows x 6 columns]

# %%
df_o3_2020
# Out:
#        Dia Mes  Anio Hora                Lugar Valor
# 0        1   1  2020    1              Acolman   -99
# 1        1   1  2020    1         Ajusco Medio   -99
# 2        1   1  2020    1               Ajusco   -99
# 3        1   1  2020    1             Atizapan     3
# 4        1   1  2020    1        Benito Juarez     2
# ...     ..  ..   ...  ...                  ...   ...
# 316183  31  12  2020   23            Tultitlan   -99
# 316184  31  12  2020   23       UAM Xochimilco    34
# 316185  31  12  2020   23       UAM Iztapalapa    18
# 316186  31  12  2020   23  Villa de las Flores     3
# 316187  31  12  2020   23             Xalostoc   -99
#
# [316188 rows x 6 columns]

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2017.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_o3_2017.to_csv(filepath)

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2018.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_o3_2018.to_csv(filepath)

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2019.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_o3_2019.to_csv(filepath)

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2020.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_o3_2020.to_csv(filepath)

# %%
o3_2016_m = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2016.csv")
o3_2017_m = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2017.csv")
o3_2018_m = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2018.csv")
o3_2019_m = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2019.csv")
o3_2020_m = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2020.csv")

# %%
df_2_o3 = pd.DataFrame()
df_2_o3 = df_2_o3.append(o3_2016_m, ignore_index=True)
df_2_o3 = df_2_o3.append(o3_2017_m, ignore_index=True)
df_2_o3 = df_2_o3.append(o3_2018_m, ignore_index=True)
df_2_o3 = df_2_o3.append(o3_2019_m, ignore_index=True)
df_2_o3 = df_2_o3.append(o3_2020_m, ignore_index=True)

df_2_o3
# Out:
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\2962623716.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_2_o3 = df_2_o3.append(o3_2016_m, ignore_index=True)
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\2962623716.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_2_o3 = df_2_o3.append(o3_2017_m, ignore_index=True)
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\2962623716.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_2_o3 = df_2_o3.append(o3_2018_m, ignore_index=True)
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\2962623716.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df_2_o3 = df_2_o3.drop(df_2_o3.columns[0], axis=1)
df_2_o3
# Out:
#          Dia  Mes  Anio  Hora                Lugar  Valor
# 0          1    1  2016     1              Acolman    -99
# 1          1    1  2016     1         Ajusco Medio     38
# 2          1    1  2016     1               Ajusco     19
# 3          1    1  2016     1             Atizapan    -99
# 4          1    1  2016     1        Benito Juarez    -99
# ...      ...  ...   ...   ...                  ...    ...
# 1534500   31   12  2020    23            Tultitlan    -99
# 1534501   31   12  2020    23       UAM Xochimilco     34
# 1534502   31   12  2020    23       UAM Iztapalapa     18
# 1534503   31   12  2020    23  Villa de las Flores      3
# 1534504   31   12  2020    23             Xalostoc    -99
#
# [1534505 rows x 6 columns]

# %%
df_2_o3
# Out:
#          Dia  Mes  Anio  Hora                Lugar Particula  Valor  \
# 0          1    1  2016     1              Acolman        O3    -99
# 1          1    1  2016     1         Ajusco Medio        O3     38
# 2          1    1  2016     1               Ajusco        O3     19
# 3          1    1  2016     1             Atizapan        O3    -99
# 4          1    1  2016     1        Benito Juarez        O3    -99
# ...      ...  ...   ...   ...                  ...       ...    ...
# 1534500   31   12  2020    23            Tultitlan        O3    -99
# 1534501   31   12  2020    23       UAM Xochimilco        O3     34
# 1534502   31   12  2020    23       UAM Iztapalapa        O3     18
# 1534503   31   12  2020    23  Villa de las Flores        O3      3
# 1534504   31   12  2020    23             Xalostoc        O3    -99
#
#                    Estado    Latitud   Longitud
# 0        Estado de México  19.635501 -98.912003
# 1        Ciudad de México  19.272161 -99.207744
# ...

# %%
df_2_o3['Particula'] = "O3"

# %%
df_2_o3 = df_2_o3[['Dia', 'Mes', 'Anio', 'Hora', 'Lugar', 'Particula', 'Valor']]

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\o3_2016_2020.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_2_o3.to_csv(filepath)

# %%
cat_estacion = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv\\cat_estacion.csv")
df_estacion = pd.DataFrame(cat_estacion)

# %%
df_o3_v2 = pd.DataFrame(columns=['Dia', 'Mes', 'Anio', 'Hora', 'Particula', 'Valor', 'Lugar', 'Estado', 'Latitud', 'Longitud'])

# %%
from geopy.geocoders import Nominatim
import time
import math

geo = Nominatim(user_agent="MyApp")

estado = {}
latitud = {}
longitud = {}
for i in range(len(df_estacion)):
    latitud[df_estacion["nom_estac"][i]] = df_estacion["latitud"][i]
    longitud[df_estacion["nom_estac"][i]] = df_estacion["longitud"][i]
    address = geo.reverse(str(df_estacion["latitud"][i]) + ", " + str(df_estacion["longitud"][i]))
    #print(address, address.latitude, address.longitude)
    #x = str(address).split(", ")
    Estado_1 = ""
    if "Ciudad de México" in str(address):
        Estado_1 = "Ciudad de México"
        #print(Estado)
    else:
        Estado_1 = "Estado de México"
    estado[df_estacion["nom_estac"][i]] = Estado_1

# %%
estado_toAdd = []
latitud_toAdd = []
longitud_toAdd = []
#estado[df_aire_100['Lugar'][0]]
for i in range(len(df_2_o3)):
    estado_toAdd.append(estado[df_2_o3['Lugar'][i]])
    latitud_toAdd.append(latitud[df_2_o3['Lugar'][i]])
    longitud_toAdd.append(longitud[df_2_o3['Lugar'][i]])

# %%
df_2_o3['Estado'] = estado_toAdd
df_2_o3['Latitud'] = latitud_toAdd
df_2_o3['Longitud'] = longitud_toAdd
# Out:
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\3276904670.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_o3['Estado'] = estado_toAdd
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\3276904670.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2_o3['Latitud'] = latitud_toAdd
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\3276904670.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df_aire_cdmx = df_2_o3[df_2_o3["Estado"].str.contains("Estado de México")==False]
df_aire_cdmx
# Out:
#          Dia  Mes  Anio  Hora                               Lugar Particula  \
# 1          1    1  2016     1                        Ajusco Medio        O3
# 2          1    1  2016     1                              Ajusco        O3
# 4          1    1  2016     1                       Benito Juarez        O3
# 5          1    1  2016     1                           Camarones        O3
# 6          1    1  2016     1  Centro de Ciencias de la Atmosfera        O3
# ...      ...  ...   ...   ...                                 ...       ...
# 1534496   31   12  2020    23                            Santa FE        O3
# 1534497   31   12  2020    23                     San Juan Aragon        O3
# 1534498   31   12  2020    23                             Tlahuac        O3
# 1534501   31   12  2020    23                      UAM Xochimilco        O3
# 1534502   31   12  2020    23                      UAM Iztapalapa        O3
#
#          Valor            Estado    Latitud   Longitud
# ...

# %%
acaldia = pd.read_csv("E:\\7mo\\TT1\\Datos_aire\\alcaldias_list.csv")
acaldia["Alcaldía"]
# Out:
# 0                 Milpa Alta
# 1              Benito Juárez
# 2          Gustavo A. Madero
# 3                   Coyoacán
# 4             Miguel Hidalgo
# 5     La Magdalena Contreras
# 6                    Tláhuac
# 7               Azcapotzalco
# 8                  Iztacalco
# 9             Álvaro Obregón
# 10                Xochimilco
# 11       Venustiano Carranza
# 12                   Tlalpan
# 13     Cuajimalpa de Morelos
# 14                Cuauhtémoc
# 15                Iztapalapa
# Name: Alcaldía, dtype: object

# %%
df_aire_cdmx["Lugar"].unique()
# Out:
# array(['Ajusco Medio', 'Ajusco', 'Benito Juarez', 'Camarones',
#        'Centro de Ciencias de la Atmosfera', 'Coyoacan', 'Cuajimalpa',
#        'Gustavo A. Madero', 'Hospital General de Mexico', 'Iztacalco',
#        'Merced', 'Miguel Hidalgo', 'Milpa Alta', 'Pedregal', 'Santa FE',
#        'San Juan Aragon', 'Tlahuac', 'UAM Xochimilco', 'UAM Iztapalapa',
#        'Lab. de Analisis Ambiental', 'Santiago Acahualtepec'],
#       dtype=object)

# %%
alcaldias_lista = {}

lugar = df_aire_cdmx["Lugar"].unique()

for k in range(len(lugar)):
    
    num_lat = df_aire_cdmx.loc[(df_aire_cdmx['Lugar'] == lugar[k])]["Latitud"].unique()[0]
    num_lon = df_aire_cdmx.loc[(df_aire_cdmx['Lugar'] == lugar[k])]["Longitud"].unique()[0]
    loc = geo.reverse((num_lat, num_lon))
    list_loc = str(loc).split(", ")
    for i in range(len(list_loc)):
        for j in range(len(acaldia)):
            if(list_loc[i].lower()==acaldia["Alcaldía"][j].lower()):
                alcaldias_lista[lugar[k]] = list_loc[i]

# %%
alcaldias_toadd = []

for i in range(len(df_aire_cdmx)):
    alcaldias_toadd.append(alcaldias_lista[df_aire_cdmx["Lugar"].values[i]])

# %%
df_aire_cdmx['Alcaldia'] = alcaldias_toadd
# Out:
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\3885829836.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aire_cdmx['Alcaldia'] = alcaldias_toadd

# %%
df_aire_cdmx
# Out:
#          Dia  Mes  Anio  Hora                               Lugar Particula  \
# 1          1    1  2016     1                        Ajusco Medio        O3
# 2          1    1  2016     1                              Ajusco        O3
# 4          1    1  2016     1                       Benito Juarez        O3
# 5          1    1  2016     1                           Camarones        O3
# 6          1    1  2016     1  Centro de Ciencias de la Atmosfera        O3
# ...      ...  ...   ...   ...                                 ...       ...
# 1534496   31   12  2020    23                            Santa FE        O3
# 1534497   31   12  2020    23                     San Juan Aragon        O3
# 1534498   31   12  2020    23                             Tlahuac        O3
# 1534501   31   12  2020    23                      UAM Xochimilco        O3
# 1534502   31   12  2020    23                      UAM Iztapalapa        O3
#
# ...

# %%
#aqi.to_iaqi(aqi.POLLUTANT_O3_1H, (df_aire_cdmx["Valor"].values[i]*0.001), algo=aqi.ALGO_EPA)
df_aire_cdmx["Valor"].values[0]*0.001
# Out:
# 0.038

# %%
import aqi
from decimal import Decimal
list_AQI = []

for i in range(len(df_aire_cdmx)):
    if(df_aire_cdmx["Particula"].values[i] == "O3"):
        if((df_aire_cdmx["Valor"].values[i] != -99) & (df_aire_cdmx["Valor"].values[i] < 200)):
            myaqi = aqi.to_iaqi(aqi.POLLUTANT_O3_8H, (df_aire_cdmx["Valor"].values[i]*0.001), algo=aqi.ALGO_EPA)
            list_AQI.append(myaqi)
        else:
            list_AQI.append(-99)
    else:
        list_AQI.append(-99)

# %%
df_aire_cdmx['AQI'] = list_AQI
# Out:
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\1047419774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aire_cdmx['AQI'] = list_AQI

# %%
df_aire_cdmx
# Out:
#          Dia  Mes  Anio  Hora                               Lugar Particula  \
# 1          1    1  2016     1                        Ajusco Medio        O3
# 2          1    1  2016     1                              Ajusco        O3
# 4          1    1  2016     1                       Benito Juarez        O3
# 5          1    1  2016     1                           Camarones        O3
# 6          1    1  2016     1  Centro de Ciencias de la Atmosfera        O3
# ...      ...  ...   ...   ...                                 ...       ...
# 1534496   31   12  2020    23                            Santa FE        O3
# 1534497   31   12  2020    23                     San Juan Aragon        O3
# 1534498   31   12  2020    23                             Tlahuac        O3
# 1534501   31   12  2020    23                      UAM Xochimilco        O3
# 1534502   31   12  2020    23                      UAM Iztapalapa        O3
#
# ...

# %%
alc_Mayus = []
a,b = 'áéíóúüñÁÉÍÓÚÜÑ','aeiouunAEIOUUN'
transform = str.maketrans(a,b)

for i in range(len(df_aire_cdmx)):
    alc_Mayus.append(df_aire_cdmx["Alcaldia"].values[i].translate(transform).upper().replace('.',''))

# %%
df_aire_cdmx["Alcaldia"] = alc_Mayus
# Out:
# C:\Users\dgonz\AppData\Local\Temp\ipykernel_15648\3641042926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aire_cdmx["Alcaldia"] = alc_Mayus

# %%
df_aire_cdmx
# Out:
#          Dia  Mes  Anio  Hora                               Lugar Particula  \
# 1          1    1  2016     1                        Ajusco Medio        O3
# 2          1    1  2016     1                              Ajusco        O3
# 4          1    1  2016     1                       Benito Juarez        O3
# 5          1    1  2016     1                           Camarones        O3
# 6          1    1  2016     1  Centro de Ciencias de la Atmosfera        O3
# ...      ...  ...   ...   ...                                 ...       ...
# 1534496   31   12  2020    23                            Santa FE        O3
# 1534497   31   12  2020    23                     San Juan Aragon        O3
# 1534498   31   12  2020    23                             Tlahuac        O3
# 1534501   31   12  2020    23                      UAM Xochimilco        O3
# 1534502   31   12  2020    23                      UAM Iztapalapa        O3
#
# ...

# %%
df_pm25_pm10_co = pd.read_csv('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_2011_2020_v6.csv')
df_pm25_pm10_co
# Out:
#          Unnamed: 0  Dia  Mes  Anio  Hora                  Lugar Particula  \
# 0                 0    1    1  2011     1              Camarones        CO
# 1                 1    1    1  2011     1             Cuajimalpa        CO
# 2                 2    1    1  2011     1              Iztacalco        CO
# 3                 3    1    1  2011     1                 Merced        CO
# 4                 4    1    1  2011     1               Pedregal        CO
# ...             ...  ...  ...   ...   ...                    ...       ...
# 3413102     3413102   31   12  2020    23               Pedregal     PM2.5
# 3413103     3413103   31   12  2020    23  Santiago Acahualtepec     PM2.5
# 3413104     3413104   31   12  2020    23               Santa FE     PM2.5
# 3413105     3413105   31   12  2020    23                Tlahuac     PM2.5
# 3413106     3413106   31   12  2020    23         UAM Iztapalapa     PM2.5
#
# ...

# %%
df_pm25_pm10_co = df_pm25_pm10_co.drop(df_pm25_pm10_co.columns[0], axis=1)

df_pm25 = df_pm25_pm10_co[(df_pm25_pm10_co['Particula'] == "PM2.5") & (df_pm25_pm10_co['Anio'] > 2015)]


df_pm25
# Out:
#          Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 2776641    1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 2776642    1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2776643    1    1  2016     1                   Camarones     PM2.5  127.0
# 2776644    1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 2776645    1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...      ...  ...   ...   ...                         ...       ...    ...
# 3413102   31   12  2020    23                    Pedregal     PM2.5   53.0
# 3413103   31   12  2020    23       Santiago Acahualtepec     PM2.5  -99.0
# 3413104   31   12  2020    23                    Santa FE     PM2.5   28.0
# 3413105   31   12  2020    23                     Tlahuac     PM2.5  -99.0
# 3413106   31   12  2020    23              UAM Iztapalapa     PM2.5   42.0
#
# ...

# %%
df_others = df_pm25_pm10_co[(df_pm25_pm10_co['Anio'] > 2015)]

# %%
df_all = pd.DataFrame()
df_all = pd.concat([df_all, df_pm25_pm10_co], ignore_index=True)
df_all = pd.concat([df_all, df_aire_cdmx], ignore_index=True)

# %%
df_all
# Out:
#          Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0          1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1          1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2          1    1  2016     1                   Camarones     PM2.5  127.0
# 3          1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4          1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...      ...  ...   ...   ...                         ...       ...    ...
# 1495779   31   12  2020    23                    Santa FE        O3   16.0
# 1495780   31   12  2020    23             San Juan Aragon        O3  -99.0
# 1495781   31   12  2020    23                     Tlahuac        O3   41.0
# 1495782   31   12  2020    23              UAM Xochimilco        O3   34.0
# 1495783   31   12  2020    23              UAM Iztapalapa        O3   18.0
#
# ...

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pm25_o3_2016_2020.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_all.to_csv(filepath)

# %%
df_filtered = df_all[(df_all['Dia'] == 1) & (df_all['Mes'] == 1) & (df_all['Anio'] == 2016) & (df_all['Hora'] == 15) & (df_all['Lugar'] == "Ajusco Medio")]
df_filtered
# Out:
#         Dia  Mes  Anio  Hora         Lugar Particula  Valor            Estado  \
# 182       1    1  2016    15  Ajusco Medio     PM2.5  106.0  Ciudad de México
# 636732    1    1  2016    15  Ajusco Medio        O3  118.0  Ciudad de México
#
#           Latitud   Longitud Alcaldia  AQI
# 182     19.272161 -99.207744  TLALPAN  177
# 636732  19.272161 -99.207744  TLALPAN  202

# %%
id_list = []
id_list2 = []

for i in range(len(df_all)):
    id_new2 = str(df_all['Dia'][i]) + '_' + str(df_all['Mes'][i]) + '_' + str(df_all['Anio'][i]) + '_' + str(df_all['Hora'][i]) + '_' + df_all['Lugar'][i] + '_' + str(df_all['Particula'][i][0:1])
    id_new = str(df_all['Dia'][i]) + '_' + str(df_all['Mes'][i]) + '_' + str(df_all['Anio'][i]) + '_' + str(df_all['Hora'][i]) + '_' + df_all['Lugar'][i]
    id_list.append(id_new)
    id_list2.append(id_new2)

df_all['ID'] = id_list
df_all['ID2'] = id_list2
df_all
# Out:
#          Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0          1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1          1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2          1    1  2016     1                   Camarones     PM2.5  127.0
# 3          1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4          1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...      ...  ...   ...   ...                         ...       ...    ...
# 1495779   31   12  2020    23                    Santa FE        O3   16.0
# 1495780   31   12  2020    23             San Juan Aragon        O3  -99.0
# 1495781   31   12  2020    23                     Tlahuac        O3   41.0
# 1495782   31   12  2020    23              UAM Xochimilco        O3   34.0
# 1495783   31   12  2020    23              UAM Iztapalapa        O3   18.0
#
# ...

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pm25_o3_2016_2020_ids.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_all.to_csv(filepath)

# %%
df_filtered = df_all[(df_all['ID'] == "1_1_2016_1_Ajusco Medio")]
df_filtered
# Out:
#         Dia  Mes  Anio  Hora         Lugar Particula  Valor            Estado  \
# 0         1    1  2016     1  Ajusco Medio     PM2.5   71.0  Ciudad de México
# 636466    1    1  2016     1  Ajusco Medio        O3   38.0  Ciudad de México
#
#           Latitud   Longitud Alcaldia  AQI                       ID  \
# 0       19.272161 -99.207744  TLALPAN  159  1_1_2016_1_Ajusco Medio
# 636466  19.272161 -99.207744  TLALPAN   31  1_1_2016_1_Ajusco Medio
#
#                               ID2
# 0       1_1_2016_1_Ajusco Medio_P
# 636466  1_1_2016_1_Ajusco Medio_O

# %%
df_o3_pm25 = pd.read_csv('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pm25_o3_2016_2020_ids.csv')
df_o3_pm25
# Out:
#          Unnamed: 0  Dia  Mes  Anio  Hora                       Lugar  \
# 0                 0    1    1  2016     1                Ajusco Medio
# 1                 1    1    1  2016     1               Benito Juarez
# 2                 2    1    1  2016     1                   Camarones
# 3                 3    1    1  2016     1                  Cuajimalpa
# 4                 4    1    1  2016     1  Hospital General de Mexico
# ...             ...  ...  ...   ...   ...                         ...
# 1495779     1495779   31   12  2020    23                    Santa FE
# 1495780     1495780   31   12  2020    23             San Juan Aragon
# 1495781     1495781   31   12  2020    23                     Tlahuac
# 1495782     1495782   31   12  2020    23              UAM Xochimilco
# 1495783     1495783   31   12  2020    23              UAM Iztapalapa
#
#         Particula  Valor            Estado    Latitud   Longitud  \
# ...

# %%
df_o3_pm25 = df_o3_pm25.drop(df_o3_pm25.columns[0], axis=1)
df_o3_pm25
# Out:
#          Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0          1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1          1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2          1    1  2016     1                   Camarones     PM2.5  127.0
# 3          1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4          1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...      ...  ...   ...   ...                         ...       ...    ...
# 1495779   31   12  2020    23                    Santa FE        O3   16.0
# 1495780   31   12  2020    23             San Juan Aragon        O3  -99.0
# 1495781   31   12  2020    23                     Tlahuac        O3   41.0
# 1495782   31   12  2020    23              UAM Xochimilco        O3   34.0
# 1495783   31   12  2020    23              UAM Iztapalapa        O3   18.0
#
# ...

# %%
#df_o3_pm25[(df_o3_pm25["Particula"] == "PM2.5")]
#df_o3_pm25[(df_o3_pm25["Particula"] == "O3")]

#df_filtered = df_all[(df_all['ID'] == "1_1_2016_1_Ajusco Medio")]
#df_filtered

#for i in df_o3_pm25["ID"]:
    
for i in df_o3_pm25["ID"]:
    #print(i)
    df_filtered = df_o3_pm25[(df_o3_pm25['ID'] == i)]
#df_filtered

# %%
df_filtered.index[1]
# Out:
# 636466

# %%
df_filtered_2 = pd.DataFrame()

for i in df_o3_pm25["ID"]:
    #print(i)
    df_filtered = df_o3_pm25[(df_o3_pm25['ID'] == i)]
    
    if (len(df_filtered) > 1):
        if (df_filtered["AQI"][df_filtered.index[0]] > df_filtered["AQI"][df_filtered.index[1]]):
            #print(df_filtered["Particula"][df_filtered.index[0]])
            df_filtered = df_filtered.drop([df_filtered.index[1]])
        else:
            df_filtered = df_filtered.drop([df_filtered.index[0]])
    
    df_filtered_2 = pd.concat([df_filtered_2, df_filtered], ignore_index=True)


df_filtered_2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 3>()
#       1 df_filtered_2 = pd.DataFrame()
#       3 for i in df_o3_pm25["ID"]:
#       4     #print(i)
# ----> 5     df_filtered = df_o3_pm25[(df_o3_pm25['ID'] == i)]
#       7     if (len(df_filtered) > 1):
#       8         if (df_filtered["AQI"][df_filtered.index[0]] > df_filtered["AQI"][df_filtered.index[1]]):
#       9             #print(df_filtered["Particula"][df_filtered.index[0]])
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
# ...

# %%
df_filtered_2
# Out:
#         Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0         1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1         1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2         1    1  2016     1                   Camarones     PM2.5  127.0
# 3         1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4         1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...     ...  ...   ...   ...                         ...       ...    ...
# 233199   17    1  2018    12                   Iztacalco     PM2.5   86.0
# 233200   17    1  2018    12                      Merced     PM2.5   84.0
# 233201   17    1  2018    12              Miguel Hidalgo     PM2.5  114.0
# 233202   17    1  2018    12                  Milpa Alta        O3   58.0
# 233203   17    1  2018    12                    Pedregal        O3   34.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
df_filtered_3 = df_filtered_2.drop_duplicates(subset=['ID2'])
df_filtered_3
# Out:
#         Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0         1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1         1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2         1    1  2016     1                   Camarones     PM2.5  127.0
# 3         1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4         1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...     ...  ...   ...   ...                         ...       ...    ...
# 233199   17    1  2018    12                   Iztacalco     PM2.5   86.0
# 233200   17    1  2018    12                      Merced     PM2.5   84.0
# 233201   17    1  2018    12              Miguel Hidalgo     PM2.5  114.0
# 233202   17    1  2018    12                  Milpa Alta        O3   58.0
# 233203   17    1  2018    12                    Pedregal        O3   34.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
df_4 = df_o3_pm25[(df_o3_pm25['ID'] == "17_1_2018_12_Pedregal")]
df_4
# Out:
#         Dia  Mes  Anio  Hora     Lugar Particula  Valor            Estado  \
# 233203   17    1  2018    12  Pedregal     PM2.5  -99.0  Ciudad de México
# 977282   17    1  2018    12  Pedregal        O3   34.0  Ciudad de México
#
#           Latitud   Longitud        Alcaldia  AQI                     ID  \
# 233203  19.325146 -99.204136  ALVARO OBREGON  -99  17_1_2018_12_Pedregal
# 977282  19.325146 -99.204136  ALVARO OBREGON   29  17_1_2018_12_Pedregal
#
#                             ID2
# 233203  17_1_2018_12_Pedregal_P
# 977282  17_1_2018_12_Pedregal_O

# %%
df_5 = df_o3_pm25.iloc[233204:]
df_5
# Out:
#          Dia  Mes  Anio  Hora            Lugar Particula  Valor  \
# 233204    17    1  2018    12         Santa FE     PM2.5   71.0
# 233205    17    1  2018    12          Tlahuac     PM2.5   66.0
# 233206    17    1  2018    12   UAM Iztapalapa     PM2.5  -99.0
# 233207    17    1  2018    13     Ajusco Medio     PM2.5   71.0
# 233208    17    1  2018    13    Benito Juarez     PM2.5   87.0
# ...      ...  ...   ...   ...              ...       ...    ...
# 1495779   31   12  2020    23         Santa FE        O3   16.0
# 1495780   31   12  2020    23  San Juan Aragon        O3  -99.0
# 1495781   31   12  2020    23          Tlahuac        O3   41.0
# 1495782   31   12  2020    23   UAM Xochimilco        O3   34.0
# 1495783   31   12  2020    23   UAM Iztapalapa        O3   18.0
#
#                    Estado    Latitud   Longitud               Alcaldia  AQI  \
# 233204   Ciudad de México  19.357357 -99.262865  CUAJIMALPA DE MORELOS  159
# ...

# %%
from time import sleep
from tqdm import tqdm, trange

# %%
len(df_5["ID"])
# Out:
# 1262580

# %%
#list_drops_ids2 = []
df_6 = pd.DataFrame()

for i in tqdm(df_5["ID"], total=len(df_5["ID"])):
    #print(i)
    df_filtered = df_5[(df_5['ID'] == i)]
    
    if (len(df_filtered) > 1):
        if (df_filtered["AQI"][df_filtered.index[0]] > df_filtered["AQI"][df_filtered.index[1]]):
            #print(df_filtered["Particula"][df_filtered.index[0]])
            df_filtered = df_filtered.drop([df_filtered.index[1]])
            #list_drops_ids2.append(df_filtered["ID2"][df_filtered.index[1]])
        else:
            df_filtered = df_filtered.drop([df_filtered.index[0]])
             #list_drops_ids2.append(df_filtered["ID2"][df_filtered.index[0]])
    
    df_6 = pd.concat([df_6, df_filtered], ignore_index=True)

df_6
#df_filtered_2
# Out:
#  36%|███▌      | 448621/1262580 [12:22:36<24:18:29,  9.30it/s]

# %%
df_filtered_3
# Out:
#         Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0         1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1         1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2         1    1  2016     1                   Camarones     PM2.5  127.0
# 3         1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4         1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...     ...  ...   ...   ...                         ...       ...    ...
# 233199   17    1  2018    12                   Iztacalco     PM2.5   86.0
# 233200   17    1  2018    12                      Merced     PM2.5   84.0
# 233201   17    1  2018    12              Miguel Hidalgo     PM2.5  114.0
# 233202   17    1  2018    12                  Milpa Alta        O3   58.0
# 233203   17    1  2018    12                    Pedregal        O3   34.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
from pathlib import Path  
filepath = Path('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pt1.csv')  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_all.to_csv(filepath)

# %%
df_aire_pt1 = pd.read_csv('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pt1.csv')
df_aire_pt2 = pd.read_csv('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pt2.csv')


df_aire_pt1 = df_aire_pt1.drop(df_aire_pt1.columns[0], axis=1)
df_aire_pt2 = df_aire_pt2.drop(df_aire_pt2.columns[0], axis=1)

# %%
df_aire_pt3 = pd.DataFrame()
df_aire_pt3 = pd.concat([df_aire_pt3, df_aire_pt1], ignore_index = True)
df_aire_pt3 = pd.concat([df_aire_pt3, df_aire_pt2], ignore_index = True)
df_aire_pt3
# Out:
#         Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0         1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1         1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2         1    1  2016     1                   Camarones     PM2.5  127.0
# 3         1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4         1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...     ...  ...   ...   ...                         ...       ...    ...
# 744835    9    4  2016    22                  Cuajimalpa        O3   61.0
# 744836    9    4  2016    22           Gustavo A. Madero        O3   40.0
# 744837    9    4  2016    22  Hospital General de Mexico        O3   43.0
# 744838    9    4  2016    22                   Iztacalco        O3   34.0
# 744839    9    4  2016    22                      Merced        O3   28.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
df_filtered_1 = df_aire_pt3.drop_duplicates(subset=['ID2'])
df_filtered_1
# Out:
#         Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0         1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1         1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2         1    1  2016     1                   Camarones     PM2.5  127.0
# 3         1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4         1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...     ...  ...   ...   ...                         ...       ...    ...
# 744835    9    4  2016    22                  Cuajimalpa        O3   61.0
# 744836    9    4  2016    22           Gustavo A. Madero        O3   40.0
# 744837    9    4  2016    22  Hospital General de Mexico        O3   43.0
# 744838    9    4  2016    22                   Iztacalco        O3   34.0
# 744839    9    4  2016    22                      Merced        O3   28.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
df_filtered_2 = df_filtered_1.drop_duplicates(subset=['ID'])
#df_filtered_2 = df_filtered_2.reset_index(True)
df_filtered_2 = df_filtered_2.reset_index(drop=True)
df_filtered_2
# Out:
#         Dia  Mes  Anio  Hora                               Lugar Particula  \
# 0         1    1  2016     1                        Ajusco Medio     PM2.5
# 1         1    1  2016     1                       Benito Juarez     PM2.5
# 2         1    1  2016     1                           Camarones     PM2.5
# 3         1    1  2016     1                          Cuajimalpa     PM2.5
# 4         1    1  2016     1          Hospital General de Mexico     PM2.5
# ...     ...  ...   ...   ...                                 ...       ...
# 619437    9    4  2016    21                      UAM Xochimilco        O3
# 619438    9    4  2016    22                              Ajusco        O3
# 619439    9    4  2016    22  Centro de Ciencias de la Atmosfera        O3
# 619440    9    4  2016    22                            Coyoacan        O3
# 619441    9    4  2016    22                   Gustavo A. Madero        O3
#
# ...

# %%
df_filtered_2["Anio"].value_counts()
# Out:
# 2020    131745
# 2019    131385
# 2016    128565
# 2017    113880
# 2018    113867
# Name: Anio, dtype: int64

# %%
df_filtered_2[df_filtered_2["Anio"] == 2020]
# Out:
#         Dia  Mes  Anio  Hora                  Lugar Particula  Valor  \
# 473311    1    1  2020     1           Ajusco Medio     PM2.5  -99.0
# 473312    1    1  2020     1          Benito Juarez     PM2.5   62.0
# 473313    1    1  2020     1              Camarones     PM2.5  -99.0
# 473314    1    1  2020     1             Cuajimalpa     PM2.5  116.0
# 473315    1    1  2020     1      Gustavo A. Madero     PM2.5  -99.0
# ...     ...  ...   ...   ...                    ...       ...    ...
# 605051   31   12  2020    23               Pedregal     PM2.5   53.0
# 605052   31   12  2020    23  Santiago Acahualtepec        O3   20.0
# 605053   31   12  2020    23               Santa FE     PM2.5   28.0
# 605054   31   12  2020    23                Tlahuac        O3   41.0
# 605055   31   12  2020    23         UAM Iztapalapa     PM2.5   42.0
#
#                   Estado    Latitud   Longitud               Alcaldia  AQI  \
# ...

# %%
df_o3_pm25[df_o3_pm25["ID"] == "9_4_2016_22_San Juan Aragon"]
# Out:
#         Dia  Mes  Anio  Hora            Lugar Particula  Valor  \
# 682024    9    4  2016    22  San Juan Aragon        O3  -99.0
#
#                   Estado    Latitud   Longitud          Alcaldia  AQI  \
# 682024  Ciudad de México  19.452592 -99.086095  GUSTAVO A MADERO  -99
#
#                                  ID                            ID2
# 682024  9_4_2016_22_San Juan Aragon  9_4_2016_22_San Juan Aragon_O

# %%
df_o3_pm25 = pd.read_csv('E:\\7mo\\TT1\\Datos_aire\\Contaminantes\\csv_modificados\\aire_pm25_o3_2016_2020_ids.csv')
df_o3_pm25 = df_o3_pm25.drop(df_o3_pm25.columns[0], axis=1)
df_o3_pm25
# Out:
#          Dia  Mes  Anio  Hora                       Lugar Particula  Valor  \
# 0          1    1  2016     1                Ajusco Medio     PM2.5   71.0
# 1          1    1  2016     1               Benito Juarez     PM2.5  100.0
# 2          1    1  2016     1                   Camarones     PM2.5  127.0
# 3          1    1  2016     1                  Cuajimalpa     PM2.5   99.0
# 4          1    1  2016     1  Hospital General de Mexico     PM2.5   88.0
# ...      ...  ...   ...   ...                         ...       ...    ...
# 1495779   31   12  2020    23                    Santa FE        O3   16.0
# 1495780   31   12  2020    23             San Juan Aragon        O3  -99.0
# 1495781   31   12  2020    23                     Tlahuac        O3   41.0
# 1495782   31   12  2020    23              UAM Xochimilco        O3   34.0
# 1495783   31   12  2020    23              UAM Iztapalapa        O3   18.0
#
# ...

# %%
df_filtered_2["ID2"]
# Out:
# 0                                1_1_2016_1_Ajusco Medio_P
# 1                               1_1_2016_1_Benito Juarez_P
# 2                                   1_1_2016_1_Camarones_P
# 3                                  1_1_2016_1_Cuajimalpa_P
# 4                  1_1_2016_1_Hospital General de Mexico_P
#                                 ...
# 619437                        9_4_2016_21_UAM Xochimilco_O
# 619438                                9_4_2016_22_Ajusco_O
# 619439    9_4_2016_22_Centro de Ciencias de la Atmosfera_O
# 619440                              9_4_2016_22_Coyoacan_O
# 619441                     9_4_2016_22_Gustavo A. Madero_O
# Name: ID2, Length: 619442, dtype: object

# %%
#df_o3_pm25_2 = df_o3_pm25[~df_o3_pm25['ID2'].isin(df_filtered_2["ID2"])]
df_o3_pm25_2 = df_o3_pm25[~df_o3_pm25['ID'].isin(df_filtered_2["ID"])]
df_o3_pm25_2
#df = df[df['Delito'].isin(delitos)]
#df.drop(df[df['Age'] < 25].index, inplace = True)
# Out:
#          Dia  Mes  Anio  Hora                               Lugar Particula  \
# 682024     9    4  2016    22                     San Juan Aragon        O3
# 682026     9    4  2016    22                      UAM Xochimilco        O3
# 682029     9    4  2016    23                              Ajusco        O3
# 682032     9    4  2016    23  Centro de Ciencias de la Atmosfera        O3
# 682033     9    4  2016    23                            Coyoacan        O3
# ...      ...  ...   ...   ...                                 ...       ...
# 1495765   31   12  2020    23                              Ajusco        O3
# 1495768   31   12  2020    23  Centro de Ciencias de la Atmosfera        O3
# 1495769   31   12  2020    23                            Coyoacan        O3
# 1495780   31   12  2020    23                     San Juan Aragon        O3
# 1495782   31   12  2020    23                      UAM Xochimilco        O3
#
# ...

# %%
df_aire_f = pd.DataFrame()
df_aire_f = pd.concat([df_aire_f, df_filtered_2], ignore_index = True)
df_aire_f = pd.concat([df_aire_f, df_o3_pm25_2], ignore_index = True)
df_aire_f
# Out:
#         Dia  Mes  Anio  Hora                               Lugar Particula  \
# 0         1    1  2016     1                        Ajusco Medio     PM2.5
# 1         1    1  2016     1                       Benito Juarez     PM2.5
# 2         1    1  2016     1                           Camarones     PM2.5
# 3         1    1  2016     1                          Cuajimalpa     PM2.5
# 4         1    1  2016     1          Hospital General de Mexico     PM2.5
# ...     ...  ...   ...   ...                                 ...       ...
# 859326   31   12  2020    23                              Ajusco        O3
# 859327   31   12  2020    23  Centro de Ciencias de la Atmosfera        O3
# 859328   31   12  2020    23                            Coyoacan        O3
# 859329   31   12  2020    23                     San Juan Aragon        O3
# 859330   31   12  2020    23                      UAM Xochimilco        O3
#
# ...

# %%
df_aire_f2 = df_aire_f.drop_duplicates(subset=['ID'])
df_aire_f2
# Out:
#         Dia  Mes  Anio  Hora                               Lugar Particula  \
# 0         1    1  2016     1                        Ajusco Medio     PM2.5
# 1         1    1  2016     1                       Benito Juarez     PM2.5
# 2         1    1  2016     1                           Camarones     PM2.5
# 3         1    1  2016     1                          Cuajimalpa     PM2.5
# 4         1    1  2016     1          Hospital General de Mexico     PM2.5
# ...     ...  ...   ...   ...                                 ...       ...
# 859326   31   12  2020    23                              Ajusco        O3
# 859327   31   12  2020    23  Centro de Ciencias de la Atmosfera        O3
# 859328   31   12  2020    23                            Coyoacan        O3
# 859329   31   12  2020    23                     San Juan Aragon        O3
# 859330   31   12  2020    23                      UAM Xochimilco        O3
#
# ...

# %%
df_aire_f3 = df_aire_f2.drop(['ID', 'ID2'], axis=1)
df_aire_f3
# Out:
#         Dia  Mes  Anio  Hora                               Lugar Particula  \
# 0         1    1  2016     1                        Ajusco Medio     PM2.5
# 1         1    1  2016     1                       Benito Juarez     PM2.5
# 2         1    1  2016     1                           Camarones     PM2.5
# 3         1    1  2016     1                          Cuajimalpa     PM2.5
# 4         1    1  2016     1          Hospital General de Mexico     PM2.5
# ...     ...  ...   ...   ...                                 ...       ...
# 859326   31   12  2020    23                              Ajusco        O3
# 859327   31   12  2020    23  Centro de Ciencias de la Atmosfera        O3
# 859328   31   12  2020    23                            Coyoacan        O3
# 859329   31   12  2020    23                     San Juan Aragon        O3
# 859330   31   12  2020    23                      UAM Xochimilco        O3
#
# ...

# %%
from pathlib import Path  
filepath = Path("../csv/aire_v3.csv")  

filepath.parent.mkdir(parents=True, exist_ok=True)  

df_aire_f4.to_csv(filepath)

# %%
df_5 = df_aire_f3[(df_aire_f3['Alcaldia'] == "IZTAPALAPA")]
df_5["Lugar"].value_counts()
# Out:
# UAM Iztapalapa           43844
# Santiago Acahualtepec    17542
# Name: Lugar, dtype: int64

# %%
df_aire_f3.rename(columns = {'Lugar':'Estacion'}, inplace = True)

# %%
df_aire_f4
# Out:
#         Dia  Mes  Anio  Hora                            Estacion  \
# 0         1    1  2016     1                        Ajusco Medio
# 1         1    1  2016     1                       Benito Juarez
# 2         1    1  2016     1                           Camarones
# 3         1    1  2016     1                          Cuajimalpa
# 4         1    1  2016     1          Hospital General de Mexico
# ...     ...  ...   ...   ...                                 ...
# 859326   31   12  2020    23                              Ajusco
# 859327   31   12  2020    23  Centro de Ciencias de la Atmosfera
# 859328   31   12  2020    23                            Coyoacan
# 859329   31   12  2020    23                     San Juan Aragon
# 859330   31   12  2020    23                      UAM Xochimilco
#
#                      Alcaldia   Longitud    Latitud Particula  Valor  AQI
# 0                     TLALPAN -99.207744  19.272161     PM2.5   71.0  159
# ...

# %%
df_aire_f3 = df_aire_f3.drop(['Estado'], axis=1)

# %%
df_aire_f4 = df_aire_f3[['Dia','Mes','Anio','Hora', 'Estacion', 'Alcaldia', 'Longitud', 'Latitud', 'Particula', 'Valor', 'AQI']]
